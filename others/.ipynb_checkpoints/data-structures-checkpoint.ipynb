# %% [markdown]
# #### Dicts.

# %% [markdown]
# english = ["one", "two", "three"]
# spanish = ["uno", "dos", "tres"]

# %%
english = ["one", "two", "three"]
spanish = ["uno", "dos", "tres"]

# %%
english.index("two")
# Out:
# 1

# %%
spanish[english.index("three")]
# Out:
# 'tres'

# %%
from bisect import bisect_left
lookup = [en for en, es in sorted(zip(english, spanish))]
value = [es for en, es in sorted(zip(english, spanish))]

key = "two"
value[bisect_left(lookup, key)]
# Out:
# 'dos'

# %%
from numpy import array, linspace
from numpy.random import choice, shuffle
from string import ascii_lowercase
from bisect import bisect_left
import timeit

MAX_SIZE = 10 ** 5

letters = array([c for c in ascii_lowercase])
words = choice(letters, size=(MAX_SIZE, 10))
words = array(["".join(w) for w in words])

ns = linspace(1, MAX_SIZE, 500, dtype=int)
list_times = []
dict_times = []
bisect_times = []

for n in ns:
    shuffle(words)

    sample_list = list(words[:n])
    sample_dict = dict.fromkeys(sample_list)
    sample_bisect = sorted(sample_list)

    lookup_words = choice(sample_list, size=10)

    list_time = %timeit  -o [sample_list.index(w) for w in lookup_words]
    dict_time = %timeit -o [sample_dict[w] for w in lookup_words]
    bisect_time = %timeit -o [bisect_left(sample_bisect, w) for w in lookup_words]

    list_times.append(list_time.best)
    dict_times.append(dict_time.best)
    bisect_times.append(bisect_time.best)
#print("list items", list_times)
#print("Dict items", dict_times)
#print("Bisect items", bisect_times)
# Out:
# 2.51 µs ± 27.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 2.65 µs ± 26.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 2.78 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 18 µs ± 226 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 2.68 µs ± 20.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 3.57 µs ± 14.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 32.3 µs ± 285 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.69 µs ± 17.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 3.75 µs ± 8.99 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 48.6 µs ± 104 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.7 µs ± 8.41 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 3.98 µs ± 18.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 52.5 µs ± 495 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.65 µs ± 4.35 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.24 µs ± 20.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 71.5 µs ± 1.05 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.74 µs ± 54.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.31 µs ± 10.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 98.5 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.84 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.42 µs ± 44.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 104 µs ± 699 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.68 µs ± 41.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.59 µs ± 59.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 122 µs ± 1.97 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.87 µs ± 45.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.47 µs ± 34.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 169 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.76 µs ± 10.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.35 µs ± 79.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 137 µs ± 2.4 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.84 µs ± 94.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.57 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 204 µs ± 1.86 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.75 µs ± 31 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.7 µs ± 115 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 216 µs ± 3.55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.85 µs ± 43.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.62 µs ± 45.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 211 µs ± 6.29 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.69 µs ± 36.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.35 µs ± 65.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 205 µs ± 1.37 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.81 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.66 µs ± 70.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 167 µs ± 590 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.69 µs ± 13.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.53 µs ± 189 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 171 µs ± 3.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.73 µs ± 9.39 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.73 µs ± 50.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 201 µs ± 2.71 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.67 µs ± 35.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.56 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 283 µs ± 4.36 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.81 µs ± 172 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.1 µs ± 424 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 305 µs ± 53.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.85 µs ± 584 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 6.25 µs ± 619 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 299 µs ± 21.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 147 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5 µs ± 329 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 386 µs ± 64.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.09 µs ± 191 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.96 µs ± 246 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 325 µs ± 54.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.93 µs ± 686 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.33 µs ± 536 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 410 µs ± 66.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.1 µs ± 227 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 6.18 µs ± 657 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 495 µs ± 44.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.98 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.95 µs ± 132 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 379 µs ± 18.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.71 µs ± 99 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.88 µs ± 87.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 489 µs ± 74.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.85 µs ± 85.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.01 µs ± 164 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 354 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.97 µs ± 92.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.3 µs ± 241 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 347 µs ± 23 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.85 µs ± 94.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.24 µs ± 137 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 420 µs ± 37.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.83 µs ± 81.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.04 µs ± 177 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 458 µs ± 4.47 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.85 µs ± 72.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.1 µs ± 279 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 592 µs ± 127 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.91 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.25 µs ± 193 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 390 µs ± 10.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.75 µs ± 104 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.84 µs ± 172 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 478 µs ± 48 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.64 µs ± 348 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.33 µs ± 83.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 443 µs ± 16.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.84 µs ± 89.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.03 µs ± 177 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 379 µs ± 17.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 49.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.75 µs ± 35.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 453 µs ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.67 µs ± 12 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.97 µs ± 78.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 580 µs ± 16.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 55.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.23 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 655 µs ± 136 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.9 µs ± 118 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 6.28 µs ± 561 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 762 µs ± 30 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.01 µs ± 258 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.21 µs ± 229 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 621 µs ± 20.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 166 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.88 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 689 µs ± 23.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.81 µs ± 99.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.15 µs ± 157 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 562 µs ± 26.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 23.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.98 µs ± 54.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 593 µs ± 25.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.72 µs ± 17.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.94 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 783 µs ± 35.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.88 µs ± 203 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.04 µs ± 48.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 402 µs ± 21.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.74 µs ± 60 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5 µs ± 59.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 467 µs ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.78 µs ± 29.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.01 µs ± 118 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 612 µs ± 21.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.83 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.18 µs ± 141 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 493 µs ± 11.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.73 µs ± 34.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.15 µs ± 165 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 597 µs ± 19.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.92 µs ± 221 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.69 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 755 µs ± 58.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.81 µs ± 137 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.12 µs ± 243 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 504 µs ± 4.46 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.74 µs ± 27.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.04 µs ± 17.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1.01 ms ± 51.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.79 µs ± 66.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.05 µs ± 98.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 784 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.78 µs ± 52.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.05 µs ± 119 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 715 µs ± 5.39 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.76 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.99 µs ± 79.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 695 µs ± 4.89 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.75 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.14 µs ± 147 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 806 µs ± 6.18 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.84 µs ± 54.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.87 µs ± 20.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 843 µs ± 9.77 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.76 µs ± 29.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.3 µs ± 235 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 916 µs ± 16 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.75 µs ± 43.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.3 µs ± 254 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 772 µs ± 22.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.84 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.19 µs ± 269 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 914 µs ± 34.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.65 µs ± 17 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 4.99 µs ± 68.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 687 µs ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.76 µs ± 54 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5.22 µs ± 96.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1.05 ms ± 40.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.21 µs ± 359 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 5
ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %matplotlib inline

# %%
from matplotlib.pyplot import figure,plot, title, legend, ylabel, xlabel, show
fig = figure(figsize=(12, 8))

plot(ns, list_times, "bo", label = u"list lookup ~ 0(n)")
plot(ns, dict_times, "go", label = u"dict lookup ~ 0(1)")
plot(ns, bisect_times, "ro", label = u"bisect lookup ~ 0(log(n)")

title("List vs dict vs bisect (binary search) lookup")
legend(loc="best")
xlabel("input size (elements)", figsize=fig)
ylabel("best time out of 3 (s)", figsize=fig)
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 from matplotlib.pyplot import figure,plot, title, legend, ylabel, xlabel, show
#       2 fig = figure(figsize=(12, 8))
# ----> 4 plot(ns, list_times, "bo", label = u"list lookup ~ 0(n)")
#       5 plot(ns, dict_times, "go", label = u"dict lookup ~ 0(1)")
#       6 plot(ns, bisect_times, "ro", label = u"bisect lookup ~ 0(log(n)")
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/axes/_base.py:2309, in _AxesBase.add_line(self, line)
#    2306 if line.get_clip_path() is None:
#    2307     line.set_clip_path(self.patch)
# -> 2309 self._update_line_limits(line)
#    2310 if not line.get_label():
#    2311     line.set_label(f'_child{len(self._children)}')
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/axes/_base.py:2332, in _AxesBase._update_line_limits(self, line)
#    2328 def _update_line_limits(self, line):
#    2329     """
#    2330     Figures out the data limit of the given line, updating self.dataLim.
#    2331     """
# -> 2332     path = line.get_path()
#    2333     if path.vertices.size == 0:
#    2334         return
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/lines.py:1032, in Line2D.get_path(self)
#    1030 """Return the `~matplotlib.path.Path` associated with this line."""
#    1031 if self._invalidy or self._invalidx:
# -> 1032     self.recache()
#    1033 return self._path
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/lines.py:674, in Line2D.recache(self, always)
#     672 if always or self._invalidy:
#     673     yconv = self.convert_yunits(self._yorig)
# --> 674     y = _to_unmasked_float_array(yconv).ravel()
#     675 else:
#     676     y = self._y
#
# File ~/anaconda3/envs/data-analysis/lib/python3.12/site-packages/matplotlib/cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'TimeitResult'
